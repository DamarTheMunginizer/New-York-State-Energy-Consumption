# %%
import requests
import pandas as pd
from datetime import datetime, timedelta

# Define the base URL for the API or dataset
BASE_URL = "https://api.nyiso.com/load_data"  # Replace this with the actual endpoint

# Function to fetch data from the API
def fetch_hourly_data(start_date, end_date):
    """
    Fetch hourly data from the API within the given date range.
    :param start_date: Start date (YYYY-MM-DD)
    :param end_date: End date (YYYY-MM-DD)
    :return: DataFrame with hourly data
    """
    data = []
    current_date = datetime.strptime(start_date, "%Y-%m-%d")
    end_date = datetime.strptime(end_date, "%Y-%m-%d")
    
    while current_date <= end_date:
        try:
            # Format the date for the API request
            date_str = current_date.strftime("%Y-%m-%d")
            print(f"Fetching data for {date_str}...")
            
            # Build the URL dynamically based on the date
            url = f"{BASE_URL}?date={date_str}"  # Adjust based on the API's query parameter structure
            
            # Make the API request
            response = requests.get(url)
            response.raise_for_status()
            daily_data = response.json()  # Assuming JSON response
            
            # Process the data (adjust based on API response structure)
            for record in daily_data["hourly_load"]:  # Update this based on actual keys in the API response
                data.append({
                    "County": record["county"],  # Adjust key names
                    "Date": record["date"],  # Adjust key names
                    "Hour": record["hour"],  # Adjust key names
                    "Consumption (MWh)": record["load"]  # Adjust key names
                })
                
        except Exception as e:
            print(f"Error fetching data for {date_str}: {e}")
        
        # Move to the next day
        current_date += timedelta(days=1)
    
    # Convert to DataFrame
    return pd.DataFrame(data)

# Fetch and save data
start_date = "2005-02-01"
end_date = "2024-12-10"
data = fetch_hourly_data(start_date, end_date)
# Out:
# Fetching data for 2005-02-01...
# Error fetching data for 2005-02-01: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-01 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-02...
# Error fetching data for 2005-02-02: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-02 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-03...
# Error fetching data for 2005-02-03: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-03 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-04...
# Error fetching data for 2005-02-04: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-04 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-05...
# Error fetching data for 2005-02-05: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-05 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-06...
# Error fetching data for 2005-02-06: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-06 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-07...
# Error fetching data for 2005-02-07: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-07 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-08...
# Error fetching data for 2005-02-08: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-08 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-09...
# Error fetching data for 2005-02-09: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-09 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-10...
# Error fetching data for 2005-02-10: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-10 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-11...
# Error fetching data for 2005-02-11: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-11 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-12...
# Error fetching data for 2005-02-12: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-12 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-13...
# Error fetching data for 2005-02-13: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-13 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-14...
# Error fetching data for 2005-02-14: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-14 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-15...
# Error fetching data for 2005-02-15: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-15 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-16...
# Error fetching data for 2005-02-16: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-16 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-17...
# Error fetching data for 2005-02-17: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-17 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-18...
# Error fetching data for 2005-02-18: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-18 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-19...
# Error fetching data for 2005-02-19: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-19 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-20...
# Error fetching data for 2005-02-20: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-20 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-21...
# Error fetching data for 2005-02-21: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-21 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-22...
# Error fetching data for 2005-02-22: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-22 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-23...
# Error fetching data for 2005-02-23: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-23 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-24...
# Error fetching data for 2005-02-24: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-24 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-25...
# Error fetching data for 2005-02-25: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-25 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-26...
# Error fetching data for 2005-02-26: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-26 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-27...
# Error fetching data for 2005-02-27: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-27 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-28...
# Error fetching data for 2005-02-28: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-28 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-03-01...
# Error fetching data for 2005-03-01: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-03-01 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-03-02...
# Error fetching data for 2005-03-02: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-03-02 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-03-03...
# Error fetching data for 2005-03-03: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-03-03 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-03-04...
# Error fetching data for 2005-03-04: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-03-04 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-03-05...
# Error fetching data for 2005-03-05: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-03
(Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-07-04...
# Error fetching data for 2005-07-04: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-07-04 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-07-05...
# Error fetching data for 2005-07-05: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-07-05 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-07-06...
# Error fetching data for 2005-07-06: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-07-06 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-07-07...
# Error fetching data for 2005-07-07: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-07-07 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-07-08...
# Error fetching data for 2005-07-08: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-07-08 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-07-09...
# Error fetching data for 2005-07-09: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-07-09 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-07-10...
# Error fetching data for 2005-07-10: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-07-10 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-07-11...
# Error fetching data for 2005-07-11: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-07-11 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-07-12...
# ...
# Fetching data for 2006-01-28...
# Error fetching data for 2006-01-28: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2006-01-28 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2006-01-29...
# Error fetching data for 2006-01-29: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2006-01-29 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2006-01-30...
# Error fetching data for 2006-01-30: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2006-01-30 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2006-01-31...
# Error fetching data for 2006-01-31: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2006-01-31 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2006-02-01...
# Error fetching data for 2006-02-01: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2006-02-01 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2006-02-02...
# Error fetching data for 2006-02-02: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2006-02-02 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2006-02-03...
# Error fetching data for 2006-02-03: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2006-02-03 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2006-02-04...
# Error fetching data for 2006-02-04: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2006-02-04 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2006-02-05...
# Error fetching data for 2006-02-05: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2006-02-05 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2006-02-06...
# Error fetching data for 2006-02-06: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2006-02-06 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2006-02-07...
# Error fetching data for 2006-02-07: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2006-02-07 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2006-02-08...
# Error fetching data for 2006-02-08: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2006-02-08 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2006-02-09...
# Error fetching data for 2006-02-09: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2006-02-09 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2006-02-10...
# Error fetching data for 2006-02-10: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2006-02-10 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2006-02-11...
# Error fetching data for 2006-02-11: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2006-02-11 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2006-02-12...
# Error fetching data for 2006-02-12: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2006-02-12 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2006-02-13...
# Error fetching data for 2006-02-13: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2006-02-13 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2006-02-14...
# Error fetching data for 2006-02-14: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2006-02-14 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2006-02-15...
# Error fetching data for 2006-02-15: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2006-02-15 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2006-02-16...
# Error fetching data for 2006-02-16: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2006-02-16 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2006-02-17...
# Error fetching data for 2006-02-17: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2006-02-17 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2006-02-18...
# Error fetching data for 2006-02-18: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2006-02-18 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2006-02-19...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 55
#      53 start_date = "2005-02-01"
#      54 end_date = "2024-12-10"
# ---> 55 data = fetch_hourly_data(start_date, end_date)
#
# Cell In[1], line 30, in fetch_hourly_data(start_date, end_date)
#      27 url = f"{BASE_URL}?date={date_str}"  # Adjust based on the API's query parameter structure
#      29 # Make the API request
# ---> 30 response = requests.get(url)
#      31 response.raise_for_status()
#      32 daily_data = response.json()  # Assuming JSON response
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\anaconda3\Lib\site-packages\requests\adapters.py:589, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     586     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     588 try:
# --> 589     resp = conn.urlopen(
#     590         method=request.method,
#     591         url=url,
#     592         body=request.body,
#     593         headers=request.headers,
#     594         redirect=False,
#     595         assert_same_host=False,
#     596         preload_content=False,
#     597         decode_content=False,
#     598         retries=self.max_retries,
#     599         timeout=timeout,
#     600         chunked=chunked,
#     601     )
#     603 except (ProtocolError, OSError) as err:
#     604     raise ConnectionError(err, request=request)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
#     464     # Trigger any extra validation we need to do.
#     465     try:
# --> 466         self._validate_conn(conn)
#     467     except (SocketTimeout, BaseSSLError) as e:
#     468         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1093 # Force connect early to allow us to validate the connection.
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1098 if not conn.is_verified and not conn.proxy_is_verified:
#
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:652, in HTTPSConnection.connect(self)
#     649 # Remove trailing '.' from fqdn hostnames to allow certificate validation
#     650 server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 652 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     653     sock=sock,
#     654     cert_reqs=self.cert_reqs,
#     655     ssl_version=self.ssl_version,
#     656     ssl_minimum_version=self.ssl_minimum_version,
#     657     ssl_maximum_version=self.ssl_maximum_version,
#     658     ca_certs=self.ca_certs,
#     659     ca_cert_dir=self.ca_cert_dir,
#     660     ca_cert_data=self.ca_cert_data,
#     661     cert_file=self.cert_file,
#     662     key_file=self.key_file,
#     663     key_password=self.key_password,
#     664     server_hostname=server_hostname_rm_dot,
#     665     ssl_context=self.ssl_context,
#     666     tls_in_tls=tls_in_tls,
#     667     assert_hostname=self.assert_hostname,
#     668     assert_fingerprint=self.assert_fingerprint,
#     669 )
#     670 self.sock = sock_and_verified.socket
#     672 # Forwarding proxies can never have a verified target since
#     673 # the proxy is the one doing the verification. Should instead
#     674 # use a CONNECT tunnel in order to verify the target.
#     675 # See: https://github.com/urllib3/urllib3/issues/3267.
#
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:805, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     802     if is_ipaddress(normalized):
#     803         server_hostname = normalized
# --> 805 ssl_sock = ssl_wrap_socket(
#     806     sock=sock,
#     807     keyfile=key_file,
#     808     certfile=cert_file,
#     809     key_password=key_password,
#     810     ca_certs=ca_certs,
#     811     ca_cert_dir=ca_cert_dir,
#     812     ca_cert_data=ca_cert_data,
#     813     server_hostname=server_hostname,
#     814     ssl_context=context,
#     815     tls_in_tls=tls_in_tls,
#     816 )
#     818 try:
#     819     if assert_fingerprint:
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\ssl_.py:465, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     462 except NotImplementedError:  # Defensive: in CI, we always have set_alpn_protocols
#     463     pass
# --> 465 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     466 return ssl_sock
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\ssl_.py:509, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     506     SSLTransport._validate_ssl_context_for_tls_in_tls(ssl_context)
#     507     return SSLTransport(sock, ssl_context, server_hostname)
# --> 509 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File ~\anaconda3\Lib\ssl.py:455, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     449 def wrap_socket(self, sock, server_side=False,
#     450                 do_handshake_on_connect=True,
#     451                 suppress_ragged_eofs=True,
#     452                 server_hostname=None, session=None):
#     453     # SSLSocket class handles server_hostname encoding before it calls
#     454     # ctx._wrap_socket()
# --> 455     return self.sslsocket_class._create(
#     456         sock=sock,
#     457         server_side=server_side,
#     458         do_handshake_on_connect=do_handshake_on_connect,
#     459         suppress_ragged_eofs=suppress_ragged_eofs,
#     460         server_hostname=server_hostname,
#     461         context=self,
#     462         session=session
#     463     )
#
# File ~\anaconda3\Lib\ssl.py:1042, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039             if timeout == 0.0:
#    1040                 # non-blocking
#    1041                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1042             self.do_handshake()
#    1043 except:
#    1044     try:
#
# File ~\anaconda3\Lib\ssl.py:1320, in SSLSocket.do_handshake(self, block)
#    1318     if timeout == 0.0 and block:
#    1319         self.settimeout(None)
# -> 1320     self._sslobj.do_handshake()
#    1321 finally:
#    1322     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.ssl_ import create_urllib3_context

class TLSAdapter(HTTPAdapter):
    def __init__(self, tls_version=None, *args, **kwargs):
        self.tls_version = tls_version
        self.context = create_urllib3_context()
        if tls_version:
            self.context.minimum_version = tls_version
        super().__init__(*args, **kwargs)

# Create a session with a specific TLS version (e.g., TLS 1.2)
session = requests.Session()
adapter = TLSAdapter()
session.mount("https://", adapter)

# Example modified fetch
def fetch_hourly_data(start_date, end_date):
    data = []
    current_date = datetime.strptime(start_date, "%Y-%m-%d")
    end_date = datetime.strptime(end_date, "%Y-%m-%d")
    
    while current_date <= end_date:
        try:
            date_str = current_date.strftime("%Y-%m-%d")
            print(f"Fetching data for {date_str}...")
            url = f"{BASE_URL}?date={date_str}"
            response = session.get(url)
            response.raise_for_status()
            daily_data = response.json()
            
            # Process data
            for record in daily_data.get("hourly_load", []):
                data.append({
                    "County": record.get("county"),
                    "Date": record.get("date"),
                    "Hour": record.get("hour"),
                    "Consumption (MWh)": record.get("load")
                })
        except Exception as e:
            print(f"Error fetching data for {date_str}: {e}")
        
        current_date += timedelta(days=1)
    
    return pd.DataFrame(data)

# Fetch data
data = fetch_hourly_data("2005-02-01", "2024-12-10")
# Out:
# Fetching data for 2005-02-01...
# Error fetching data for 2005-02-01: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-01 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-02...
# Error fetching data for 2005-02-02: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-02 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-03...
# Error fetching data for 2005-02-03: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-03 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-04...
# Error fetching data for 2005-02-04: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-04 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-05...
# Error fetching data for 2005-02-05: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-05 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-06...
# Error fetching data for 2005-02-06: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-06 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-07...
# Error fetching data for 2005-02-07: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-07 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-08...
# Error fetching data for 2005-02-08: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-08 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-09...
# Error fetching data for 2005-02-09: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-09 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-10...
# Error fetching data for 2005-02-10: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-10 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-11...
# Error fetching data for 2005-02-11: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-11 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-12...
# Error fetching data for 2005-02-12: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-12 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-13...
# Error fetching data for 2005-02-13: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-13 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-14...
# Error fetching data for 2005-02-14: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-14 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-15...
# Error fetching data for 2005-02-15: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-15 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-16...
# Error fetching data for 2005-02-16: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-16 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-17...
# Error fetching data for 2005-02-17: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-17 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-18...
# Error fetching data for 2005-02-18: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-18 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-19...
# Error fetching data for 2005-02-19: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-19 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-20...
# Error fetching data for 2005-02-20: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-20 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-21...
# Error fetching data for 2005-02-21: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-21 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-22...
# Error fetching data for 2005-02-22: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-22 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-23...
# Error fetching data for 2005-02-23: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-23 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-24...
# Error fetching data for 2005-02-24: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-24 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-25...
# Error fetching data for 2005-02-25: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-25 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-26...
# Error fetching data for 2005-02-26: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-26 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-27...
# Error fetching data for 2005-02-27: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-27 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-02-28...
# Error fetching data for 2005-02-28: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-02-28 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-03-01...
# Error fetching data for 2005-03-01: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-03-01 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-03-02...
# Error fetching data for 2005-03-02: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-03-02 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-03-03...
# Error fetching data for 2005-03-03: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-03-03 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-03-04...
# Error fetching data for 2005-03-04: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-03-04 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-03-05...
# Error fetching data for 2005-03-05: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-03-05 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-03-06...
# Error fetching data for 2005-03-06: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-03-06 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-03-07...
# Error fetching data for 2005-03-07: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-03-07 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-03-08...
# Error fetching data for 2005-03-08: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-03-08 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-03-09...
# Error fetching data for 2005-03-09: HTTPSConnectionPool(host='api.nyiso.com', port=443): Max retries exceeded with url: /load_data?date=2005-03-09 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1000)')))
# Fetching data for 2005-03-10...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 49
#      46     return pd.DataFrame(data)
#      48 # Fetch data
# ---> 49 data = fetch_hourly_data("2005-02-01", "2024-12-10")
#
# Cell In[2], line 29, in fetch_hourly_data(start_date, end_date)
#      27 print(f"Fetching data for {date_str}...")
#      28 url = f"{BASE_URL}?date={date_str}"
# ---> 29 response = session.get(url)
#      30 response.raise_for_status()
#      31 daily_data = response.json()
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\anaconda3\Lib\site-packages\requests\adapters.py:589, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     586     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     588 try:
# --> 589     resp = conn.urlopen(
#     590         method=request.method,
#     591         url=url,
#     592         body=request.body,
#     593         headers=request.headers,
#     594         redirect=False,
#     595         assert_same_host=False,
#     596         preload_content=False,
#     597         decode_content=False,
#     598         retries=self.max_retries,
#     599         timeout=timeout,
#     600         chunked=chunked,
#     601     )
#     603 except (ProtocolError, OSError) as err:
#     604     raise ConnectionError(err, request=request)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
#     464     # Trigger any extra validation we need to do.
#     465     try:
# --> 466         self._validate_conn(conn)
#     467     except (SocketTimeout, BaseSSLError) as e:
#     468         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1093 # Force connect early to allow us to validate the connection.
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1098 if not conn.is_verified and not conn.proxy_is_verified:
#
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:615, in HTTPSConnection.connect(self)
#     613 def connect(self) -> None:
#     614     sock: socket.socket | ssl.SSLSocket
# --> 615     self.sock = sock = self._new_conn()
#     616     server_hostname: str = self.host
#     617     tls_in_tls = False
#
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:196, in HTTPConnection._new_conn(self)
#     191 """Establish a socket connection and set nodelay settings on it.
#     192
#     193 :return: New socket connection.
#     194 """
#     195 try:
# --> 196     sock = connection.create_connection(
#     197         (self._dns_host, self.port),
#     198         self.timeout,
#     199         source_address=self.source_address,
#     200         socket_options=self.socket_options,
#     201     )
#     202 except socket.gaierror as e:
#     203     raise NameResolutionError(self.host, self, e) from e
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      71 if source_address:
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#      75 err = None
#
# KeyboardInterrupt:

# %%
from requests.adapters import Retry

retry_strategy = Retry(
    total=5,
    backoff_factor=1,
    status_forcelist=[429, 500, 502, 503, 504]
)
adapter = HTTPAdapter(max_retries=retry_strategy)
session.mount("https://", adapter)
