# %%
import numpy as np
import pandas as pd

# %%
# imports needed for open-meteo.com data
from retry_requests import retry
import openmeteo_requests
import requests_cache
from requests.adapters import Retry
import time
import random
import os


# Setup cached session with retry functionality
cache_session = requests_cache.CachedSession('.cache', expire_after=3600)
retry = Retry(total=5, backoff_factor=0.2)
retry_session = requests_cache.CachedSession('.cache', expire_after=3600)
openmeteo = openmeteo_requests.Client(session=retry_session)

# List of coordinates (latitude, longitude)
coordinates = [
    (42.6, -73.97), (42.5273, -73.908), (42.6632, -73.8903),
    (42.25, -78.02), (42.3408, -77.9462), (42.1825, -77.966),
    (40.85, -73.8667),
    (42.17, -75.82), (42.0935, -75.8327), (42.2335, -75.8336),
    (42.25, -78.68), (42.1957, -78.6287), (42.3213, -78.6293),
    (42.95, -76.56), (43.0382, -76.524), (43.0324, -76.6587),
    (42.25, -79.37), (42.3169, -79.3912), (42.2706, -79.4473),
    (42.15, -76.75), (42.1932, -76.8433), (42.2487, -76.6562),
    (42.5, -75.6), (42.509, -75.5603), (42.5852, -75.5167),
    (44.75, -73.7), (44.7984, -73.7165), (44.819, -73.7095),
    (42.25, -73.63), (42.1683, -73.687), (42.1781, -73.5694),
    (42.6, -76.0), (42.6139, -76.086), (42.5666, -76.0895),
    (42.2, -74.95), (42.213, -74.982), (42.1821, -74.9847),
    (41.75, -73.74), (41.8488, -73.757), (41.7248, -73.6964),
    (42.77, -78.64), (42.8206, -78.673), (42.839, -78.7131),
    (44.1, -73.77), (44.0899, -73.8463), (44.0396, -73.6853),
    (44.59, -74.34), (44.4999, -74.4129), (44.6333, -74.3266),
    (43.1, -74.43), (43.1869, -74.5102), (43.038, -74.3446),
    (43.0, -78.19), (42.9548, -78.0943), (42.932, -78.1732),
    (42.3, -74.13), (42.2518, -74.1249), (42.3921, -74.2229),
    (43.67, -74.5), (43.6537, -74.4334), (43.7283, -74.5597),
    (43.42, -74.98), (43.5023, -75.0579), (43.4821, -74.8937),
    (44.0, -75.92), (44.0255, -76.0046), (44.0407, -75.9948),
    (40.65, -73.95),
    (43.79, -75.46), (43.8139, -75.5525), (43.848, -75.4359),
    (42.73, -77.78), (42.6432, -77.706), (42.7847, -77.7621),
    (42.9, -75.7), (42.9976, -75.7697), (42.8931, -75.6475),
    (43.15, -77.62), (43.1521, -77.5636), (43.1053, -77.6019),
    (42.9, -74.42), (42.9634, -74.4109), (42.8675, -74.47),
    (40.74, -73.64),
    (40.7831, -73.9712),
    (43.31, -78.97), (43.3969, -78.972), (43.3256, -78.9341),
    (43.24, -75.43), (43.3357, -75.3502), (43.1585, -75.5288),
    (43.0, -76.2), (42.9936, -76.1988), (43.014, -76.1712),
    (42.85, -77.28), (42.9361, -77.2098), (42.815, -77.1844),
    (41.4, -74.3), (41.4114, -74.3941), (41.4477, -74.2001),
    (43.25, -78.23), (43.3, -78.2743), (43.2886, -78.1854),
    (43.46, -76.27), (43.487, -76.2653), (43.5173, -76.2727),
    (42.66, -75.0), (42.5666, -75.0284), (42.7171, -75.0154),
    (41.43, -73.74),
    (40.742, -73.7694),
    (42.71, -73.51), (42.6241, -73.4122), (42.6497, -73.5621),
    (40.5795, -74.1502),
    (41.15, -73.95),
    (44.45, -75.0), (44.3836, -75.0768), (44.425, -74.9352),
    (43.1, -73.86), (43.0371, -73.9361), (43.1261, -73.8703),
    (42.81, -73.95),
    (42.66, -74.31), (42.6428, -74.4031), (42.6698, -74.3269),
    (42.38, -76.9), (42.4407, -76.915), (42.3183, -76.8097),
    (42.83, -76.83), (42.9109, -76.7693), (42.7416, -76.8044),
    (42.27, -77.38), (42.3368, -77.3559), (42.2979, -77.4301),
    (40.96, -72.69), (40.8938, -72.6109), (40.8888, -72.6118),
    (41.7, -74.77), (41.6114, -74.8241), (41.616, -74.7274),
    (42.17, -76.35), (42.1724, -76.3101), (42.2179, -76.298),
    (42.45, -76.47), (42.5157, -76.4528), (42.5222, -76.4449),
    (41.93, -74.27), (42.0144, -74.1736), (42.0277, -74.2152),
    (43.58, -73.77), (43.6572, -73.8086), (43.5552, -73.6773),
    (43.35, -73.42), (43.2725, -73.4727), (43.3773, -73.4402),
    (43.07, -77.0), (43.1199, -77.0886), (43.0837, -77.0676),
    (41.15, -73.75), (41.0824, -73.7235), (41.1497, -73.8129),
    (42.73, -78.21), (42.6543, -78.2517), (42.7225, -78.1886),
    (42.65, -77.1)
]


# Function to fetch weather data for a single location
def fetch_weather_data(lat, lon):
    url = "https://archive-api.open-meteo.com/v1/archive"
    params = {
        "latitude": lat,
        "longitude": lon,
        "start_date": "2005-01-01",
        "end_date": "2005-12-31",
        "daily": [
            'temperature_2m_max','temperature_2m_min',"daylight_duration", "sunshine_duration",'uv_index_max', 'uv_index_clear_sky_max', "rain_sum", "showers_sum",
            "snowfall_sum", "precipitation_hours", "wind_speed_10m_max", "wind_gusts_10m_max"
        ],
        "timezone": "America/New_York"
    }

    response = openmeteo.weather_api(url, params=params)[0]

    daily = response.Daily()
    daily_data = {
        "date": pd.date_range(
            start=pd.to_datetime(daily.Time(), unit="s", utc=True),
            end=pd.to_datetime(daily.TimeEnd(), unit="s", utc=True),
            freq=pd.Timedelta(seconds=daily.Interval()),
            inclusive="left"
        ),
        'temperature_2m_max': daily.Variables(0).ValuesAsNumpy(),
        'temperature_2m_min': daily.Variables(1).ValuesAsNumpy(),
        'daylight_duration': daily.Variables(2).ValuesAsNumpy(),
        'sunshine_duration': daily.Variables(3).ValuesAsNumpy(),
        'uv_index_max': daily.Variables(4).ValuesAsNumpy(),
        'uv_index_clear_sky_max': daily.Variables(5).ValuesAsNumpy(),
        'rain_sum': daily.Variables(6).ValuesAsNumpy(),
        'showers_sum': daily.Variables(7).ValuesAsNumpy(),
        'snowfall_sum': daily.Variables(8).ValuesAsNumpy(),
        'precipitation_hours': daily.Variables(9).ValuesAsNumpy(),
        'wind_speed_10m_max': daily.Variables(10).ValuesAsNumpy(),
        'wind_gusts_10m_max': daily.Variables(11).ValuesAsNumpy(),
        "latitude": [lat] * len(daily.Variables(0).ValuesAsNumpy()),
        "longitude": [lon] * len(daily.Variables(0).ValuesAsNumpy()),
    }
    return pd.DataFrame(data=daily_data)

# Main data collection function with comprehensive rate limiting and early stopping
def collect_weather_data(coordinates, max_retries=3, daily_api_limit=10000):
    dataframes = []
    failed_coordinates = []
    request_count = 0
    hourly_request_count = 0
    daily_request_count = 0
    
    for i, (lat, lon) in enumerate(coordinates, 1):
        # Stop collection BEFORE making a request if daily API limit is reached
        if daily_request_count >= daily_api_limit:
            print(f"Daily API limit of {daily_api_limit} requests reached. Stopping data collection early.")
            break
        
        retries = 0
        success = False
        
        while retries < max_retries and not success:
            try:
                print(f"Fetching weather data for coordinates: {lat}, {lon} (Location {i}/{len(coordinates)}, Attempt {retries + 1})")
                
                # Fetch data for the current location
                df = fetch_weather_data(lat, lon)
                dataframes.append(df)
                
                request_count += 1
                hourly_request_count += 1
                daily_request_count += 1
                success = True
                
                # Add delay every 3 requests
                if request_count % 3 == 0:
                    delay = random.uniform(2.5, 4.5)
                    print(f"Pausing for {delay:.2f} seconds to manage request rate...")
                    time.sleep(delay)
                
                # Check and pause for hourly limit
                if hourly_request_count >= 5000:
                    print("Hourly API request limit reached. Pausing for 3600 seconds (1 hour)...")
                    time.sleep(3600)
                    hourly_request_count = 0
            
            except Exception as e:
                error_message = str(e)
                retries += 1
                
                # Check for rate limit errors
                if 'Minutely API request limit exceeded' in error_message:
                    print("API minutely rate limit reached. Pausing for 65 seconds...")
                    time.sleep(65)  # Pause for slightly over a minute
                elif 'Hourly API request limit exceeded' in error_message:
                    print("API hourly rate limit reached. Pausing for 3600 seconds (1 hour)...")
                    time.sleep(3600)
                    hourly_request_count = 0
                else:
                    print(f"Error: {error_message}")
                    print(f"Waiting 10 seconds before retrying (Attempt {retries}/{max_retries})...")
                    time.sleep(10)
        
        # If all retry attempts fail, add to failed coordinates
        if not success:
            print(f"Failed to fetch data for coordinates {lat}, {lon} after {max_retries} attempts")
            failed_coordinates.append((lat, lon))
    
    # Print failed coordinates and request count if any
    if failed_coordinates:
        print("\nFailed to fetch data for the following coordinates:")
        for coord in failed_coordinates:
            print(coord)
    
    print(f"Total requests made: {daily_request_count}")
    
    return pd.concat(dataframes, ignore_index=True), failed_coordinates

# Collect and save data
try:
    # Create data directory if it doesn't exist
    os.makedirs('./data', exist_ok=True)
    
    # Collect weather data
    combined_dataframe, failed_coords = collect_weather_data(coordinates)
    
    # Save to CSV
    combined_dataframe.to_csv('./data/new-new-york-weather.csv', mode='a', index=False)
    
    # Save failed coordinates to a separate file
    if failed_coords:
        failed_coords_df = pd.DataFrame(failed_coords, columns=['Latitude', 'Longitude'])
        failed_coords_df.to_csv('./data/failed_coordinates.csv', index=False)
        print(f"Saved {len(failed_coords)} failed coordinates to './data/failed_coordinates.csv'")
    
    print("Weather data collection completed and saved to CSV.")

except Exception as e:
    print(f"An error occurred during data collection: {e}")
# Out:
# Fetching weather data for coordinates: 42.6, -73.97 (Location 1/166, Attempt 1)
# Fetching weather data for coordinates: 42.5273, -73.908 (Location 2/166, Attempt 1)
# Fetching weather data for coordinates: 42.6632, -73.8903 (Location 3/166, Attempt 1)
# Pausing for 3.75 seconds to manage request rate...
# Fetching weather data for coordinates: 42.25, -78.02 (Location 4/166, Attempt 1)
# Fetching weather data for coordinates: 42.3408, -77.9462 (Location 5/166, Attempt 1)
# Fetching weather data for coordinates: 42.1825, -77.966 (Location 6/166, Attempt 1)
# Pausing for 2.80 seconds to manage request rate...
# Fetching weather data for coordinates: 40.85, -73.8667 (Location 7/166, Attempt 1)
# Fetching weather data for coordinates: 42.17, -75.82 (Location 8/166, Attempt 1)
# Fetching weather data for coordinates: 42.0935, -75.8327 (Location 9/166, Attempt 1)
# Pausing for 3.02 seconds to manage request rate...
# Fetching weather data for coordinates: 42.2335, -75.8336 (Location 10/166, Attempt 1)
# Fetching weather data for coordinates: 42.25, -78.68 (Location 11/166, Attempt 1)
# Fetching weather data for coordinates: 42.1957, -78.6287 (Location 12/166, Attempt 1)
# Pausing for 3.43 seconds to manage request rate...
# Fetching weather data for coordinates: 42.3213, -78.6293 (Location 13/166, Attempt 1)
# Fetching weather data for coordinates: 42.95, -76.56 (Location 14/166, Attempt 1)
# Fetching weather data for coordinates: 43.0382, -76.524 (Location 15/166, Attempt 1)
# Pausing for 2.76 seconds to manage request rate...
# Fetching weather data for coordinates: 43.0324, -76.6587 (Location 16/166, Attempt 1)
# Fetching weather data for coordinates: 42.25, -79.37 (Location 17/166, Attempt 1)
# Fetching weather data for coordinates: 42.3169, -79.3912 (Location 18/166, Attempt 1)
# Pausing for 2.94 seconds to manage request rate...
# Fetching weather data for coordinates: 42.2706, -79.4473 (Location 19/166, Attempt 1)
# Fetching weather data for coordinates: 42.15, -76.75 (Location 20/166, Attempt 1)
# Fetching weather data for coordinates: 42.1932, -76.8433 (Location 21/166, Attempt 1)
# API minutely rate limit reached. Pausing for 65 seconds...
# Fetching weather data for coordinates: 42.1932, -76.8433 (Location 21/166, Attempt 2)
# Pausing for 4.42 seconds to manage request rate...
# Fetching weather data for coordinates: 42.2487, -76.6562 (Location 22/166, Attempt 1)
# Fetching weather data for coordinates: 42.5, -75.6 (Location 23/166, Attempt 1)
# Fetching weather data for coordinates: 42.509, -75.5603 (Location 24/166, Attempt 1)
# Pausing for 3.35 seconds to manage request rate...
# Fetching weather data for coordinates: 42.5852, -75.5167 (Location 25/166, Attempt 1)
# Fetching weather data for coordinates: 44.75, -73.7 (Location 26/166, Attempt 1)
# Fetching weather data for coordinates: 44.7984, -73.7165 (Location 27/166, Attempt 1)
# Pausing for 2.72 seconds to manage request rate...
# Fetching weather data for coordinates: 44.819, -73.7095 (Location 28/166, Attempt 1)
# Fetching weather data for coordinates: 42.25, -73.63 (Location 29/166, Attempt 1)
# Fetching weather data for coordinates: 42.1683, -73.687 (Location 30/166, Attempt 1)
# Pausing for 3.60 seconds to manage request rate...
# Fetching weather data for coordinates: 42.1781, -73.5694 (Location 31/166, Attempt 1)
# Fetching weather data for coordinates: 42.6, -76.0 (Location 32/166, Attempt 1)
# Fetching weather data for coordinates: 42.6139, -76.086 (Location 33/166, Attempt 1)
# Pausing for 3.82 seconds to manage request rate...
# Fetching weather data for coordinates: 42.5666, -76.0895 (Location 34/166, Attempt 1)
# Fetching weather data for coordinates: 42.2, -74.95 (Location 35/166, Attempt 1)
# Fetching weather data for coordinates: 42.213, -74.982 (Location 36/166, Attempt 1)
# Pausing for 3.61 seconds to manage request rate...
# Fetching weather data for coordinates: 42.1821, -74.9847 (Location 37/166, Attempt 1)
# Fetching weather data for coordinates: 41.75, -73.74 (Location 38/166, Attempt 1)
# Fetching weather data for coordinates: 41.8488, -73.757 (Location 39/166, Attempt 1)
# Pausing for 2.68 seconds to manage request rate...
# Fetching weather data for coordinates: 41.7248, -73.6964 (Location 40/166, Attempt 1)
# Fetching weather data for coordinates: 42.77, -78.64 (Location 41/166, Attempt 1)
# API minutely rate limit reached. Pausing for 65 seconds...
# Fetching weather data for coordinates: 42.77, -78.64 (Location 41/166, Attempt 2)
# Fetching weather data for coordinates: 42.8206, -78.673 (Location 42/166, Attempt 1)
# Pausing for 4.27 seconds to manage request rate...
# Fetching weather data for coordinates: 42.839, -78.7131 (Location 43/166, Attempt 1)
# Fetching weather data for coordinates: 44.1, -73.77 (Location 44/166, Attempt 1)
# Fetching weather data for coordinates: 44.0899, -73.8463 (Location 45/166, Attempt 1)
# Pausing for 2.95 seconds to manage request rate...
# Fetching weather data for coordinates: 44.0396, -73.6853 (Location 46/166, Attempt 1)
# Fetching weather data for coordinates: 44.59, -74.34 (Location 47/166, Attempt 1)
# Fetching weather data for coordinates: 44.4999, -74.4129 (Location 48/166, Attempt 1)
# Pausing for 4.10 seconds to manage request rate...
# Fetching weather data for coordinates: 44.6333, -74.3266 (Location 49/166, Attempt 1)
# Fetching weather data for coordinates: 43.1, -74.43 (Location 50/166, Attempt 1)
# Fetching weather data for coordinates: 43.1869, -74.5102 (Location 51/166, Attempt 1)
# Pausing for 3.01 seconds to manage request rate...
# Fetching weather data for coordinates: 43.038, -74.3446 (Location 52/166, Attempt 1)
# Fetching weather data for coordinates: 43.0, -78.19 (Location 53/166, Attempt 1)
# Fetching weather data for coordinates: 42.9548, -78.0943 (Location 54/166, Attempt 1)
# Pausing for 2.79 seconds to manage request rate...
# Fetching weather data for coordinates: 42.932, -78.1732 (Location 55/166, Attempt 1)
# Fetching weather data for coordinates: 42.3, -74.13 (Location 56/166, Attempt 1)
# Fetching weather data for coordinates: 42.2518, -74.1249 (Location 57/166, Attempt 1)
# Pausing for 3.49 seconds to manage request rate...
# Fetching weather data for coordinates: 42.3921, -74.2229 (Location 58/166, Attempt 1)
# Fetching weather data for coordinates: 43.67, -74.5 (Location 59/166, Attempt 1)
# Fetching weather data for coordinates: 43.6537, -74.4334 (Location 60/166, Attempt 1)
# Pausing for 3.21 seconds to manage request rate...
# Fetching weather data for coordinates: 43.7283, -74.5597 (Location 61/166, Attempt 1)
# Fetching weather data for coordinates: 43.42, -74.98 (Location 62/166, Attempt 1)
# Fetching weather data for coordinates: 43.5023, -75.0579 (Location 63/166, Attempt 1)
# Pausing for 3.47 seconds to manage request rate...
# Fetching weather data for coordinates: 43.4821, -74.8937 (Location 64/166, Attempt 1)
# Fetching weather data for coordinates: 44.0, -75.92 (Location 65/166, Attempt 1)
# Fetching weather data for coordinates: 44.0255, -76.0046 (Location 66/166, Attempt 1)
# Pausing for 3.05 seconds to manage request rate...
# Fetching weather data for coordinates: 44.0407, -75.9948 (Location 67/166, Attempt 1)
# Fetching weather data for coordinates: 40.65, -73.95 (Location 68/166, Attempt 1)
# Fetching weather data for coordinates: 43.79, -75.46 (Location 69/166, Attempt 1)
# Pausing for 3.95 seconds to manage request rate...
# Fetching weather data for coordinates: 43.8139, -75.5525 (Location 70/166, Attempt 1)
# Fetching weather data for coordinates: 43.848, -75.4359 (Location 71/166, Attempt 1)
# Fetching weather data for coordinates: 42.73, -77.78 (Location 72/166, Attempt 1)
# Pausing for 2.64 seconds to manage request rate...
# Fetching weather data for coordinates: 42.6432, -77.706 (Location 73/166, Attempt 1)
# Fetching weather data for coordinates: 42.7847, -77.7621 (Location 74/166, Attempt 1)
# Fetching weather data for coordinates: 42.9, -75.7 (Location 75/166, Attempt 1)
# Pausing for 4.03 seconds to manage request rate...
# Fetching weather data for coordinates: 42.9976, -75.7697 (Location 76/166, Attempt 1)
# Fetching weather data for coordinates: 42.8931, -75.6475 (Location 77/166, Attempt 1)
# Fetching weather data for coordinates: 43.15, -77.62 (Location 78/166, Attempt 1)
# Pausing for 4.37 seconds to manage request rate...
# Fetching weather data for coordinates: 43.1521, -77.5636 (Location 79/166, Attempt 1)
# Fetching weather data for coordinates: 43.1053, -77.6019 (Location 80/166, Attempt 1)
# Fetching weather data for coordinates: 42.9, -74.42 (Location 81/166, Attempt 1)
# API minutely rate limit reached. Pausing for 65 seconds...
# Fetching weather data for coordinates: 42.9, -74.42 (Location 81/166, Attempt 2)
# Pausing for 3.11 seconds to manage request rate...
# Fetching weather data for coordinates: 42.9634, -74.4109 (Location 82/166, Attempt 1)
# Fetching weather data for coordinates: 42.8675, -74.47 (Location 83/166, Attempt 1)
# Fetching weather data for coordinates: 40.74, -73.64 (Location 84/166, Attempt 1)
# Pausing for 4.28 seconds to manage request rate...
# Fetching weather data for coordinates: 40.7831, -73.9712 (Location 85/166, Attempt 1)
# Fetching weather data for coordinates: 43.31, -78.97 (Location 86/166, Attempt 1)
# Fetching weather data for coordinates: 43.3969, -78.972 (Location 87/166, Attempt 1)
# Pausing for 4.49 seconds to manage request rate...
# Fetching weather data for coordinates: 43.3256, -78.9341 (Location 88/166, Attempt 1)
# Fetching weather data for coordinates: 43.24, -75.43 (Location 89/166, Attempt 1)
# Fetching weather data for coordinates: 43.3357, -75.3502 (Location 90/166, Attempt 1)
# Pausing for 3.61 seconds to manage request rate...
# Fetching weather data for coordinates: 43.1585, -75.5288 (Location 91/166, Attempt 1)
# Fetching weather data for coordinates: 43.0, -76.2 (Location 92/166, Attempt 1)
# Fetching weather data for coordinates: 42.9936, -76.1988 (Location 93/166, Attempt 1)
# Pausing for 3.67 seconds to manage request rate...
# Fetching weather data for coordinates: 43.014, -76.1712 (Location 94/166, Attempt 1)
# Fetching weather data for coordinates: 42.85, -77.28 (Location 95/166, Attempt 1)
# Fetching weather data for coordinates: 42.9361, -77.2098 (Location 96/166, Attempt 1)
# Pausing for 3.04 seconds to manage request rate...
# Fetching weather data for coordinates: 42.815, -77.1844 (Location 97/166, Attempt 1)
# Fetching weather data for coordinates: 41.4, -74.3 (Location 98/166, Attempt 1)
# Fetching weather data for coordinates: 41.4114, -74.3941 (Location 99/166, Attempt 1)
# Pausing for 2.66 seconds to manage request rate...
# Fetching weather data for coordinates: 41.4477, -74.2001 (Location 100/166, Attempt 1)
# Fetching weather data for coordinates: 43.25, -78.23 (Location 101/166, Attempt 1)
# API minutely rate limit reached. Pausing for 65 seconds...
# Fetching weather data for coordinates: 43.25, -78.23 (Location 101/166, Attempt 2)
# Fetching weather data for coordinates: 43.3, -78.2743 (Location 102/166, Attempt 1)
# Pausing for 2.58 seconds to manage request rate...
# Fetching weather data for coordinates: 43.2886, -78.1854 (Location 103/166, Attempt 1)
# Fetching weather data for coordinates: 43.46, -76.27 (Location 104/166, Attempt 1)
# Fetching weather data for coordinates: 43.487, -76.2653 (Location 105/166, Attempt 1)
# Pausing for 3.58 seconds to manage request rate...
# Fetching weather data for coordinates: 43.5173, -76.2727 (Location 106/166, Attempt 1)
# Fetching weather data for coordinates: 42.66, -75.0 (Location 107/166, Attempt 1)
# Fetching weather data for coordinates: 42.5666, -75.0284 (Location 108/166, Attempt 1)
# Pausing for 4.16 seconds to manage request rate...
# Fetching weather data for coordinates: 42.7171, -75.0154 (Location 109/166, Attempt 1)
# Fetching weather data for coordinates: 41.43, -73.74 (Location 110/166, Attempt 1)
# Fetching weather data for coordinates: 40.742, -73.7694 (Location 111/166, Attempt 1)
# Pausing for 3.74 seconds to manage request rate...
# Fetching weather data for coordinates: 42.71, -73.51 (Location 112/166, Attempt 1)
# Fetching weather data for coordinates: 42.6241, -73.4122 (Location 113/166, Attempt 1)
# Fetching weather data for coordinates: 42.6497, -73.5621 (Location 114/166, Attempt 1)
# Pausing for 3.56 seconds to manage request rate...
# Fetching weather data for coordinates: 40.5795, -74.1502 (Location 115/166, Attempt 1)
# Fetching weather data for coordinates: 41.15, -73.95 (Location 116/166, Attempt 1)
# Fetching weather data for coordinates: 44.45, -75.0 (Location 117/166, Attempt 1)
# Pausing for 2.59 seconds to manage request rate...
# Fetching weather data for coordinates: 44.3836, -75.0768 (Location 118/166, Attempt 1)
# Fetching weather data for coordinates: 44.425, -74.9352 (Location 119/166, Attempt 1)
# Fetching weather data for coordinates: 43.1, -73.86 (Location 120/166, Attempt 1)
# Pausing for 2.63 seconds to manage request rate...
# Fetching weather data for coordinates: 43.0371, -73.9361 (Location 121/166, Attempt 1)
# API minutely rate limit reached. Pausing for 65 seconds...
# Fetching weather data for coordinates: 43.0371, -73.9361 (Location 121/166, Attempt 2)
# Fetching weather data for coordinates: 43.1261, -73.8703 (Location 122/166, Attempt 1)
# Fetching weather data for coordinates: 42.81, -73.95 (Location 123/166, Attempt 1)
# Pausing for 2.51 seconds to manage request rate...
# Fetching weather data for coordinates: 42.66, -74.31 (Location 124/166, Attempt 1)
# Fetching weather data for coordinates: 42.6428, -74.4031 (Location 125/166, Attempt 1)
# Fetching weather data for coordinates: 42.6698, -74.3269 (Location 126/166, Attempt 1)
# Pausing for 4.34 seconds to manage request rate...
# Fetching weather data for coordinates: 42.38, -76.9 (Location 127/166, Attempt 1)
# Fetching weather data for coordinates: 42.4407, -76.915 (Location 128/166, Attempt 1)
# Fetching weather data for coordinates: 42.3183, -76.8097 (Location 129/166, Attempt 1)
# Pausing for 3.60 seconds to manage request rate...
# Fetching weather data for coordinates: 42.83, -76.83 (Location 130/166, Attempt 1)
# Fetching weather data for coordinates: 42.9109, -76.7693 (Location 131/166, Attempt 1)
# Fetching weather data for coordinates: 42.7416, -76.8044 (Location 132/166, Attempt 1)
# Pausing for 2.98 seconds to manage request rate...
# Fetching weather data for coordinates: 42.27, -77.38 (Location 133/166, Attempt 1)
# Fetching weather data for coordinates: 42.3368, -77.3559 (Location 134/166, Attempt 1)
# Fetching weather data for coordinates: 42.2979, -77.4301 (Location 135/166, Attempt 1)
# Pausing for 4.06 seconds to manage request rate...
# Fetching weather data for coordinates: 40.96, -72.69 (Location 136/166, Attempt 1)
# Fetching weather data for coordinates: 40.8938, -72.6109 (Location 137/166, Attempt 1)
# Fetching weather data for coordinates: 40.8888, -72.6118 (Location 138/166, Attempt 1)
# Pausing for 4.46 seconds to manage request rate...
# Fetching weather data for coordinates: 41.7, -74.77 (Location 139/166, Attempt 1)
# Fetching weather data for coordinates: 41.6114, -74.8241 (Location 140/166, Attempt 1)
# Fetching weather data for coordinates: 41.616, -74.7274 (Location 141/166, Attempt 1)
# API minutely rate limit reached. Pausing for 65 seconds...
# Fetching weather data for coordinates: 41.616, -74.7274 (Location 141/166, Attempt 2)
# Pausing for 3.36 seconds to manage request rate...
# Fetching weather data for coordinates: 42.17, -76.35 (Location 142/166, Attempt 1)
# Fetching weather data for coordinates: 42.1724, -76.3101 (Location 143/166, Attempt 1)
# Fetching weather data for coordinates: 42.2179, -76.298 (Location 144/166, Attempt 1)
# Pausing for 3.55 seconds to manage request rate...
# Fetching weather data for coordinates: 42.45, -76.47 (Location 145/166, Attempt 1)
# Fetching weather data for coordinates: 42.5157, -76.4528 (Location 146/166, Attempt 1)
# Fetching weather data for coordinates: 42.5222, -76.4449 (Location 147/166, Attempt 1)
# Pausing for 4.23 seconds to manage request rate...
# Fetching weather data for coordinates: 41.93, -74.27 (Location 148/166, Attempt 1)
# Fetching weather data for coordinates: 42.0144, -74.1736 (Location 149/166, Attempt 1)
# Fetching weather data for coordinates: 42.0277, -74.2152 (Location 150/166, Attempt 1)
# Pausing for 2.77 seconds to manage request rate...
# Fetching weather data for coordinates: 43.58, -73.77 (Location 151/166, Attempt 1)
# Fetching weather data for coordinates: 43.6572, -73.8086 (Location 152/166, Attempt 1)
# Fetching weather data for coordinates: 43.5552, -73.6773 (Location 153/166, Attempt 1)
# Pausing for 4.01 seconds to manage request rate...
# Fetching weather data for coordinates: 43.35, -73.42 (Location 154/166, Attempt 1)
# Fetching weather data for coordinates: 43.2725, -73.4727 (Location 155/166, Attempt 1)
# Fetching weather data for coordinates: 43.3773, -73.4402 (Location 156/166, Attempt 1)
# Pausing for 3.44 seconds to manage request rate...
# Fetching weather data for coordinates: 43.07, -77.0 (Location 157/166, Attempt 1)
# Fetching weather data for coordinates: 43.1199, -77.0886 (Location 158/166, Attempt 1)
# Fetching weather data for coordinates: 43.0837, -77.0676 (Location 159/166, Attempt 1)
# Pausing for 2.56 seconds to manage request rate...
# Fetching weather data for coordinates: 41.15, -73.75 (Location 160/166, Attempt 1)
# Fetching weather data for coordinates: 41.0824, -73.7235 (Location 161/166, Attempt 1)
# API minutely rate limit reached. Pausing for 65 seconds...
# Fetching weather data for coordinates: 41.0824, -73.7235 (Location 161/166, Attempt 2)
# Fetching weather data for coordinates: 41.1497, -73.8129 (Location 162/166, Attempt 1)
# Pausing for 4.28 seconds to manage request rate...
# Fetching weather data for coordinates: 42.73, -78.21 (Location 163/166, Attempt 1)
# Fetching weather data for coordinates: 42.6543, -78.2517 (Location 164/166, Attempt 1)
# Fetching weather data for coordinates: 42.7225, -78.1886 (Location 165/166, Attempt 1)
# Pausing for 3.92 seconds to manage request rate...
# Fetching weather data for coordinates: 42.65, -77.1 (Location 166/166, Attempt 1)
# Total requests made: 166
# Weather data collection completed and saved to CSV.
